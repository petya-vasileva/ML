# %%
from model.IndicesRawData import IndicesRawData
IndicesRawData()
# Out:
# Success
# ps_throughput 0
# ps_retransmits 0
# ps_throughput 0
# ps_packetloss 0
# ps_throughput ps_retransmits 0
# ps_throughput0
# 0
# ps_retransmits ps_retransmits0
# ps_packetloss 0
# 0
# ps_owd ps_owd0
# 0
# ps_retransmits 0
# ps_packetloss 0
# ps_trace 0
# ps_packetloss 0
# ps_trace 0
# ps_owd 0
# ps_throughput 0
# ps_trace 0
# ps_owd 0
# ps_trace 0
# ps_throughputps_throughput  00
#
# ps_retransmits 0
# ps_retransmitsps_retransmits  00
# ps_retransmits
#  0
# ps_throughputps_throughput  00
#
# ps_retransmits 0
# ps_throughput 0
# ps_throughput 0
# ps_throughput ps_throughput0
# 0
# ps_retransmits 0
# ps_retransmits 0
# ps_retransmits 0ps_retransmits
#  0ps_packetloss
#  10000
# ps_throughput 0
# ps_throughput 0
# ps_throughput 0
# ps_throughput 0
# ps_retransmits ps_retransmits0
# 0
# ps_retransmits ps_retransmits0
# 0
# ps_throughputps_throughput  00
#
# ps_retransmits 0
# ps_retransmits 0
# ps_throughput ps_throughput0
# 0
# ps_retransmitsps_retransmits  00
#
# ...

# %%
from model.MetaData import MetaData
# %time MetaData()
# Out:
# /home/petya/ML/exploratory_analysis/model/queries.py:137: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pairsDf = pairsDf.append(aggrs)
# /home/petya/ML/exploratory_analysis/model/queries.py:137: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pairsDf = pairsDf.append(aggrs)
# /home/petya/ML/exploratory_analysis/model/queries.py:137: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pairsDf = pairsDf.append(aggrs)
# /home/petya/ML/exploratory_analysis/model/queries.py:137: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pairsDf = pairsDf.append(aggrs)
# ...

# %%
import shutil, os

location = 'data/petya/paruet'
try:
    shutil.rmtree(location)
except OSError as e:
    print("Error: %s : %s" % (dir_locationpath, e.strerror))

try:
    os.makedirs(location)
    os.makedirs(f'{location}/raw')
    os.makedirs(f'{location}/trace_and_loss')
    os.makedirs(f'{location}/augmented')
except OSError as e:
    pass
